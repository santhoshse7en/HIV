# %% [markdown]
# ### tweety - Python Package to access the Twitter database without API
#
# - pip install tweety

# %%
from twitter.tweety import tweets

# %% [markdown]
# ### Parse argument of specific Twitter keyword. In our case its 'HIV'

# %%
tweety = tweets('HIV')
# Out:
# calculating time  150  seconds taken to parse all the tweets from twitter
# total tweets are : 300

# %% [markdown]
# tweety directory

# %%
print(dir(tweety))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'final_sentiment_scores', 'tweets', 'tweets_df']

# %% [markdown]
# HIV related tweets DataFrame include Polarity Scores

# %%
tweety.tweets_df
# Out:
#                                                 tweets sentiment  \
# 0    AIDS activists — drawn from an older generatio...  positive
# 1    People who spread HIV/AIDS to others deserve t...  negative
# 2    AOC asked this pharma exec why a life-saving H...  positive
# 3    yesterday, on the first day of pride month, jo...  positive
# 4    Nearly 700 people, mostly children, were infec...  positive
# 5    omg, 8 teenagers na ang HIV/AIDS positive sa t...  positive
# 6    She was refused treatment for HIV, which is no...  negative
# 7    We are currently attending an event held by @N...   neutral
# 8    Despite being active on social media, Maryam N...  negative
# 9    Let us test today, know our status and protect...  positive
# 10   Trump called Meghan Markle “nasty” right befor...  negative
# 11   with herpes all you get is baby acne w hiv you...   neutral
# 12   how much does eharmony cost hiv dating pisces ...  positive
# ...

# %% [markdown]
# Final Sentiment Score for all tweets related to 'HIV'

# %%
tweety.final_sentiment_scores
# Out:
# {'neu': 0.835, 'neg': 0.063, 'pos': 0.102, 'compound': 0.0}
