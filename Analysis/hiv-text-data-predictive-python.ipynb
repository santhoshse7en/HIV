# %% [markdown]
# ### Installing necessary packages
#
# - pip install -U gensim

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from gensim.scripts.glove2word2vec import glove2word2vec
from gensim.models import KeyedVectors # load the Stanford GloVe model

from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
stop = stopwords.words('english')

from textblob import TextBlob
from textblob import Word

import pandas as pd
import numpy as np
import re
# Out:
# C:\Users\GM\Anaconda3\lib\site-packages\smart_open\ssh.py:34: UserWarning: paramiko missing, opening SSH/SCP/SFTP paths will be disabled.  `pip install paramiko` to suppress
#   warnings.warn('paramiko missing, opening SSH/SCP/SFTP paths will be disabled.  `pip install paramiko` to suppress')
# C:\Users\GM\Anaconda3\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %% [markdown]
# ### Reading the csv file and droping the Nan values and resetting index values

# %%
train = pd.read_csv('Final_HIV_without_Nan.csv')
train.head()
# Out:
#                                            Headlines  \
# 0  Drug â€˜can greatly reduce risk of HIV infecti...
# 1  Afghanistan recorded 1367 HIV/AIDS positive ca...
# 2  Afghanistan sees 38 percent increase in HIV/AI...
# 3  Over 1,200 people live with HIV in Afghanistan...
# 4     Aishwarya Rai Bachchan named UN HIV/AIDS envoy
#
#                                       Descriptions               Authors  \
# 0  The largest online news service for Afghanistan          Khaama Press
# 1  The largest online news service for Afghanistan  Ahmad Shah Ghanizada
# 2  The largest online news service for Afghanistan  Ahmad Shah Ghanizada
# 3  The largest online news service for Afghanistan           Sayed Jawad
# 4  The largest online news service for Afghanistan                 Sajad
#
#   Published_Dates                   Publication  \
# 0      25-11-2010  The Khaama Press News Agency
# 1      06-07-2013  The Khaama Press News Agency
# 2      01-12-2013  The Khaama Press News Agency
# 3      01-12-2012  The Khaama Press News Agency
# 4      25-09-2012  The Khaama Press News Agency
#
#                                             Articles category  \
# 0  A drug used to treat HIV-positive patients may...       {}
# 1  At least 1,367 positive cases of Human immunod...       {}
# 2  Officials in the ministry of public health of ...       {}
# 3  Today marks World AIDS Day, a time for the glo...       {}
# 4  The United Nations Monday announced the additi...       {}
#
#                                             Keywords  \
# 0  ['drug', 'reduce', 'infection', 'results', 'us...
# 1  ['afghanistan', 'paikan', 'positive', '2011', ...
# 2  ['afghanistan', 'positive', 'sees', 'virus', '...
# 3  ['immunodeficiency', '1200', 'aids', 'afghanis...
# 4  ['infections', 'mother', 'aishwarya', 'rai', '...
#
#                                            Summaries  \
# 0  A drug used to treat HIV-positive patients may...
# 1  At least 1,367 positive cases of Human immunod...
# 2  Officials in the ministry of public health of ...
# 3  Today marks World AIDS Day, a time for the glo...
# 4  The United Nations Monday announced the additi...
#
#                                          Source_URLs
# 0  https://www.khaama.com/drug-can-greatly-reduce...
# 1  https://www.khaama.com/afghanistan-recorded-13...
# 2  https://www.khaama.com/afghanistan-sees-38-per...
# 3  https://www.khaama.com/over-1200-people-live-w...
# 4  https://www.khaama.com/aishwarya-rai-bachchan-...

# %% [markdown]
# ### Basic feature extraction using text data
# - Number of words
# - Number of characters
# - Average word length
# - Number of stopwords
# - Number of special characters
# - Number of numerics
# - Number of uppercase words

# %% [markdown]
# ### Number of words

# %%
train['word_count'] = train['Articles'].apply(lambda x: len(str(x).split(" ")))
train[['Articles','word_count']].head()
# Out:
#                                             Articles  word_count
# 0  A drug used to treat HIV-positive patients may...         621
# 1  At least 1,367 positive cases of Human immunod...         272
# 2  Officials in the ministry of public health of ...         169
# 3  Today marks World AIDS Day, a time for the glo...         221
# 4  The United Nations Monday announced the additi...         231

# %% [markdown]
# ### Number of characters

# %%
train['char_count'] = train['Articles'].str.len() ## this also includes spaces
train[['Articles','char_count']].head()
# Out:
#                                             Articles  char_count
# 0  A drug used to treat HIV-positive patients may...        3658
# 1  At least 1,367 positive cases of Human immunod...        1695
# 2  Officials in the ministry of public health of ...        1053
# 3  Today marks World AIDS Day, a time for the glo...        1341
# 4  The United Nations Monday announced the additi...        1450

# %% [markdown]
# ### Average word length

# %%
def avg_word(sentence):
    words = sentence.split()
    return (sum(len(word) for word in words)/len(words))

train['avg_word'] = train['Articles'].apply(lambda x: avg_word(x))
train[['Articles','avg_word']].head()
# Out:
#                                             Articles  avg_word
# 0  A drug used to treat HIV-positive patients may...  4.892110
# 1  At least 1,367 positive cases of Human immunod...  5.235294
# 2  Officials in the ministry of public health of ...  5.236686
# 3  Today marks World AIDS Day, a time for the glo...  5.072398
# 4  The United Nations Monday announced the additi...  5.281385

# %% [markdown]
# ### Number of stopwords

# %%
train['stopwords'] = train['Articles'].apply(lambda x: len([x for x in x.split() if x in stop]))
train[['Articles','stopwords']].head()
# Out:
#                                             Articles  stopwords
# 0  A drug used to treat HIV-positive patients may...        246
# 1  At least 1,367 positive cases of Human immunod...         99
# 2  Officials in the ministry of public health of ...         58
# 3  Today marks World AIDS Day, a time for the glo...         80
# 4  The United Nations Monday announced the additi...         82

# %% [markdown]
# ### Number of special characters

# %%
train['special_characters'] = train['Articles'].apply(lambda x: len([x for x in x.split() if x.startswith('#')]))
train[['Articles','special_characters']].head()
# Out:
#                                             Articles  special_characters
# 0  A drug used to treat HIV-positive patients may...                   0
# 1  At least 1,367 positive cases of Human immunod...                   0
# 2  Officials in the ministry of public health of ...                   0
# 3  Today marks World AIDS Day, a time for the glo...                   0
# 4  The United Nations Monday announced the additi...                   0

# %% [markdown]
# ### Number of numerics

# %%
train['numerics'] = train['Articles'].apply(lambda x: len([x for x in x.split() if x.isdigit()]))
train[['Articles','numerics']].head()
# Out:
#                                             Articles  numerics
# 0  A drug used to treat HIV-positive patients may...         0
# 1  At least 1,367 positive cases of Human immunod...         1
# 2  Officials in the ministry of public health of ...         4
# 3  Today marks World AIDS Day, a time for the glo...         5
# 4  The United Nations Monday announced the additi...         8

# %% [markdown]
# ### Number of uppercase words

# %%
train['upper'] = train['Articles'].apply(lambda x: len([x for x in x.split() if x.isupper()]))
train[['Articles','upper']].head()
# Out:
#                                             Articles  upper
# 0  A drug used to treat HIV-positive patients may...     16
# 1  At least 1,367 positive cases of Human immunod...     11
# 2  Officials in the ministry of public health of ...      8
# 3  Today marks World AIDS Day, a time for the glo...     15
# 4  The United Nations Monday announced the additi...     10

# %% [markdown]
# ### Basic Text Pre-processing of text data
# - Lower casing
# - Punctuation removal
# - Stopwords removal
# - Frequent words removal
# - Rare words removal
# - Spelling correction
# - Tokenization
# - Stemming
# - Lemmatization

# %% [markdown]
# ### Lower casing

# %%
train['Articles'] = train['Articles'].apply(lambda x: " ".join(x.lower() for x in x.split()))
train['Articles'].head()
# Out:
# 0    a drug used to treat hiv-positive patients may...
# 1    at least 1,367 positive cases of human immunod...
# 2    officials in the ministry of public health of ...
# 3    today marks world aids day, a time for the glo...
# 4    the united nations monday announced the additi...
# Name: Articles, dtype: object

# %% [markdown]
# ### Punctuation removal

# %%
train['Articles'] = train['Articles'].str.replace('[^\w\s]','')
train['Articles'].head()
# Out:
# 0    a drug used to treat hivpositive patients may ...
# 1    at least 1367 positive cases of human immunode...
# 2    officials in the ministry of public health of ...
# 3    today marks world aids day a time for the glob...
# 4    the united nations monday announced the additi...
# Name: Articles, dtype: object

# %% [markdown]
# ### Stopwords removal

# %%
train['Articles'] = train['Articles'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
train['Articles'].head()
# Out:
# 0    drug used treat hivpositive patients may offer...
# 1    least 1367 positive cases human immunodeficien...
# 2    officials ministry public health afghanistan i...
# 3    today marks world aids day time global communi...
# 4    united nations monday announced addition bolly...
# Name: Articles, dtype: object

# %% [markdown]
# ### Common word removal

# %%
freq = pd.Series(' '.join(train['Articles']).split()).value_counts()[:10]
freq
# Out:
# hiv          2914
# said         2248
# hivaids      1845
# people       1698
# health       1342
# treatment     849
# aids          803
# nam           696
# city          689
# also          675
# dtype: int64

# %%
freq = list(freq.index)
train['Articles'] = train['Articles'].apply(lambda x: " ".join(x for x in x.split() if x not in freq))
train['Articles'].head()
# Out:
# 0    drug used treat hivpositive patients may offer...
# 1    least 1367 positive cases human immunodeficien...
# 2    officials ministry public afghanistan informed...
# 3    today marks world day time global community re...
# 4    united nations monday announced addition bolly...
# Name: Articles, dtype: object

# %% [markdown]
# ### Rare words removal

# %%
freq = pd.Series(' '.join(train['Articles']).split()).value_counts()[-10:]
freq
# Out:
# moveâ         1
# honda         1
# feedback      1
# tâs           1
# skull         1
# vnä7515       1
# systemsâ      1
# capacities    1
# qarizada      1
# soul          1
# dtype: int64

# %%
freq = list(freq.index)
train['Articles'] = train['Articles'].apply(lambda x: " ".join(x for x in x.split() if x not in freq))
train['Articles'].head()
# Out:
# 0    drug used treat hivpositive patients may offer...
# 1    least 1367 positive cases human immunodeficien...
# 2    officials ministry public afghanistan informed...
# 3    today marks world day time global community re...
# 4    united nations monday announced addition bolly...
# Name: Articles, dtype: object

# %% [markdown]
# ### Spelling correction

# %%
train['Articles'][:5].apply(lambda x: str(TextBlob(x).correct()))
# Out:
# 0    drug used treat hivpositive patients may offer...
# 1    least 1367 positive cases human immunodeficien...
# 2    officials ministry public afghanistan informed...
# 3    today marks world day time global community re...
# 4    united nations monday announced addition bolly...
# Name: Articles, dtype: object

# %% [markdown]
# ### Tokenization

# %%
TextBlob(train['Articles'][1]).words
# Out:
# WordList(['least', '1367', 'positive', 'cases', 'human', 'immunodeficiency', 'virus', 'recorded', 'afghanistan', 'according', 'public', 'ministry', 'afghanistan', 'public', 'officials', 'called', 'latest', 'statistics', 'worrying', 'majority', 'individuals', 'using', 'syringes', 'inject', 'drugs', 'affected', 'virus', 'head', 'human', 'immunodeficiency', 'virus', 'department', 'public', 'ministry', 'afghanistan', 'dr', 'fida', 'mohammad', 'paikan', 'majority', 'positive', 'cases', 'recorded', 'capital', 'kabul', 'lowest', 'number', 'postive', 'cases', 'recorded', 'western', 'badghis', 'province', 'afghanistan', 'dr', 'paikan', 'added', 'public', 'ministry', 'afghanistan', 'cooperation', 'un', 'world', 'organization', 'united', 'nations', 'office', 'drugs', 'crime', 'provide', 'latest', 'statistic', 'positive', 'cases', 'annually', 'least', '1367', 'positive', 'cases', 'recorded', 'end', '2011', 'dr', 'paikan', 'adding', 'number', 'could', 'statistics', 'include', 'individuals', 'volunteerly', 'done', 'tests', 'dr', 'fida', 'mohammad', 'paikan', 'latest', 'data', '2012', 'released', 'end', '2013', 'according', 'public', 'officials', 'first', 'positive', 'case', 'recorded', 'afghanistan', 'earlier', '1989', 'virus', 'mainly', 'transferred', 'afghansitan', 'migrants', 'coming', 'afghanistan', 'neighboring', 'countries', 'officials', 'saying', 'individuals', 'addicted', 'drugs', 'mainly', 'transferring', 'virus', 'using', 'single', 'syringe', 'injecting', 'drugs', 'around', '5000', 'drug', 'affected', 'individuals', 'currently', 'treated', 'across', 'country', 'bid', 'prevent', 'flow', 'virus'])

# %% [markdown]
# ### Stemming

# %%
st = PorterStemmer()
train['Articles'][:5].apply(lambda x: " ".join([st.stem(word) for word in x.split()]))
# Out:
# 0    drug use treat hivposit patient may offer gay ...
# 1    least 1367 posit case human immunodefici viru ...
# 2    offici ministri public afghanistan inform incr...
# 3    today mark world day time global commun recogn...
# 4    unit nation monday announc addit bollywood ico...
# Name: Articles, dtype: object

# %% [markdown]
# ### Lemmatization

# %%
train['Articles'] = train['Articles'].apply(lambda x: " ".join([Word(word).lemmatize() for word in x.split()]))
train['Articles'].head()
# Out:
# 0    drug used treat hivpositive patient may offer ...
# 1    least 1367 positive case human immunodeficienc...
# 2    official ministry public afghanistan informed ...
# 3    today mark world day time global community rec...
# 4    united nation monday announced addition bollyw...
# Name: Articles, dtype: object

# %% [markdown]
# ### Advance Text Processing
# - N-grams
# - Term Frequency
# - Inverse Document Frequency
# - Term Frequency-Inverse Document Frequency (TF-IDF)
# - Bag of Words
# - Sentiment Analysis
# - Word Embedding

# %% [markdown]
# ### N-grams

# %%
TextBlob(train['Articles'][0]).ngrams(2)
# Out:
# [WordList(['drug', 'used']),
#  WordList(['used', 'treat']),
#  WordList(['treat', 'hivpositive']),
#  WordList(['hivpositive', 'patient']),
#  WordList(['patient', 'may']),
#  WordList(['may', 'offer']),
#  WordList(['offer', 'gay']),
#  WordList(['gay', 'bisexual']),
#  WordList(['bisexual', 'men']),
#  WordList(['men', 'protection']),
#  WordList(['protection', 'contracting']),
#  WordList(['contracting', 'virus']),
#  WordList(['virus', 'author']),
#  WordList(['author', 'new']),
#  WordList(['new', 'study']),
#  WordList(['study', 'say']),
#  WordList(['say', 'trial']),
#  WordList(['trial', 'combination']),
#  WordList(['combination', 'drug']),
#  WordList(['drug', 'truvada']),
#  WordList(['truvada', 'among']),
#  WordList(['among', 'nearly']),
#  WordList(['nearly', '2500']),
#  WordList(['2500', 'men']),
#  WordList(['men', 'suggested']),
#  WordList(['suggested', 'could']),
#  WordList(['could', 'reduce']),
#  WordList(['reduce', 'chance']),
#  WordList(['chance', 'maletomale']),
#  WordList(['maletomale', 'infection']),
#  WordList(['infection', '44']),
#  WordList(['44', 'using']),
#  WordList(['using', 'drug']),
#  WordList(['drug', 'regularly']),
#  WordList(['regularly', 'could']),
#  WordList(['could', 'reduce']),
#  WordList(['reduce', 'risk']),
#  WordList(['risk', 'infection']),
#  WordList(['infection', 'claimed']),
#  WordList(['claimed', 'study']),
#  WordList(['study', 'published']),
#  WordList(['published', 'new']),
#  WordList(['new', 'england']),
#  WordList(['england', 'journal']),
#  WordList(['journal', 'medicine']),
#  WordList(['medicine', 'pill']),
#  WordList(['pill', 'condom']),
#  WordList(['condom', 'truvada']),
#  WordList(['truvada', 'trade']),
#  WordList(['trade', 'name']),
#  WordList(['name', 'drug']),
#  WordList(['drug', 'manufactured']),
#  WordList(['manufactured', 'californiabased']),
#  WordList(['californiabased', 'company']),
#  WordList(['company', 'gilead']),
#  WordList(['gilead', 'science']),
#  WordList(['science', 'inc']),
#  WordList(['inc', 'combine']),
#  WordList(['combine', 'two']),
#  WordList(['two', 'antiretroviral']),
#  WordList(['antiretroviral', 'drug']),
#  WordList(['drug', 'used']),
#  WordList(['used', 'treat']),
#  WordList(['treat', 'new']),
#  WordList(['new', 'study']),
#  WordList(['study', 'look']),
#  WordList(['look', 'whether']),
#  WordList(['whether', 'could']),
#  WordList(['could', 'used']),
#  WordList(['used', 'prevent']),
#  WordList(['prevent', 'infection']),
#  WordList(['infection', 'first']),
#  WordList(['first', 'place']),
#  WordList(['place', 'almost']),
#  WordList(['almost', '2500']),
#  WordList(['2500', 'gay']),
#  WordList(['gay', 'bisexual']),
#  WordList(['bisexual', 'men']),
#  WordList(['men', 'randomly']),
#  WordList(['randomly', 'selected']),
#  WordList(['selected', 'peru']),
#  WordList(['peru', 'ecuador']),
#  WordList(['ecuador', 'brazil']),
#  WordList(['brazil', 'south']),
#  WordList(['south', 'africa']),
#  WordList(['africa', 'thailand']),
#  WordList(['thailand', 'united']),
#  WordList(['united', 'state']),
#  WordList(['state', 'half']),
#  WordList(['half', 'given']),
#  WordList(['given', 'pill']),
#  WordList(['pill', 'half']),
#  WordList(['half', 'given']),
#  WordList(['given', 'dummy']),
#  WordList(['dummy', 'tablet']),
#  WordList(['tablet', 'men']),
#  WordList(['men', 'given']),
#  WordList(['given', 'condom']),
#  WordList(['condom', 'counselling']),
#  WordList(['counselling', 'safe']),
#  WordList(['safe', 'sex']),
#  WordList(['sex', 'researcher']),
#  WordList(['researcher', 'found']),
#  WordList(['found', 'year']),
#  WordList(['year', 'testing']),
#  WordList(['testing', 'drug']),
#  WordList(['drug', 'appeared']),
#  WordList(['appeared', 'cut']),
#  WordList(['cut', 'maletomale']),
#  WordList(['maletomale', 'transmission']),
#  WordList(['transmission', '44']),
#  WordList(['44', 'group']),
#  WordList(['group', 'taking']),
#  WordList(['taking', 'pill']),
#  WordList(['pill', 'compared']),
#  WordList(['compared', 'placebo']),
#  WordList(['placebo', 'group']),
#  WordList(['group', 'took']),
#  WordList(['took', 'pill']),
#  WordList(['pill', 'regularly']),
#  WordList(['regularly', 'deemed']),
#  WordList(['deemed', 'reduced']),
#  WordList(['reduced', 'risk']),
#  WordList(['risk', 'infection']),
#  WordList(['infection', '73']),
#  WordList(['73', 'blood']),
#  WordList(['blood', 'test']),
#  WordList(['test', 'run']),
#  WordList(['run', 'confirm']),
#  WordList(['confirm', 'relationship']),
#  WordList(['relationship', 'pillusage']),
#  WordList(['pillusage', 'protection']),
#  WordList(['protection', 'level']),
#  WordList(['level', 'research']),
#  WordList(['research', 'funded']),
#  WordList(['funded', 'bill']),
#  WordList(['bill', 'melinda']),
#  WordList(['melinda', 'gate']),
#  WordList(['gate', 'foundation']),
#  WordList(['foundation', 'federal']),
#  WordList(['federal', 'u']),
#  WordList(['u', 'body']),
#  WordList(['body', 'national']),
#  WordList(['national', 'institute']),
#  WordList(['institute', 'allergy']),
#  WordList(['allergy', 'infectious']),
#  WordList(['infectious', 'disease']),
#  WordList(['disease', 'niaid']),
#  WordList(['niaid', 'pill']),
#  WordList(['pill', 'donated']),
#  WordList(['donated', 'manufacturer']),
#  WordList(['manufacturer', 'niaid']),
#  WordList(['niaid', 'director']),
#  WordList(['director', 'dr']),
#  WordList(['dr', 'anthony']),
#  WordList(['anthony', 'fauci']),
#  WordList(['fauci', 'conceded']),
#  WordList(['conceded', 'work']),
#  WordList(['work', 'needed']),
#  WordList(['needed', 'done']),
#  WordList(['done', 'called']),
#  WordList(['called', 'result']),
#  WordList(['result', 'impressive']),
#  WordList(['impressive', 'âœthis']),
#  WordList(['âœthis', 'done']),
#  WordList(['done', 'men']),
#  WordList(['men', 'sex']),
#  WordList(['sex', 'men']),
#  WordList(['men', 'need']),
#  WordList(['need', 'know']),
#  WordList(['know', 'get']),
#  WordList(['get', 'similar']),
#  WordList(['similar', 'result']),
#  WordList(['result', 'woman']),
#  WordList(['woman', 'well']),
#  WordList(['well', 'heterosexual']),
#  WordList(['heterosexual', 'men']),
#  WordList(['men', 'reason']),
#  WordList(['reason', 'believe']),
#  WordList(['believe', 'willâ']),
#  WordList(['willâ', 'told']),
#  WordList(['told', 'bbc']),
#  WordList(['bbc', 'âœwe']),
#  WordList(['âœwe', 'need']),
#  WordList(['need', 'get']),
#  WordList(['get', 'long']),
#  WordList(['long', 'term']),
#  WordList(['term', 'view']),
#  WordList(['view', 'toxicity']),
#  WordList(['toxicity', 'didnât']),
#  WordList(['didnât', 'see']),
#  WordList(['see', 'anything']),
#  WordList(['anything', 'significant']),
#  WordList(['significant', 'need']),
#  WordList(['need', 'follow']),
#  WordList(['follow', 'long']),
#  WordList(['long', 'period']),
#  WordList(['period', 'timeâ']),
#  WordList(['timeâ', 'question']),
#  WordList(['question', 'concern']),
#  WordList(['concern', 'trial']),
#  WordList(['trial', 'course']),
#  WordList(['course', 'raise']),
#  WordList(['raise', 'question']),
#  WordList(['question', 'concern']),
#  WordList(['concern', 'possible']),
#  WordList(['possible', 'instance']),
#  WordList(['instance', 'result']),
#  WordList(['result', 'skewed']),
#  WordList(['skewed', 'greater']),
#  WordList(['greater', 'condom']),
#  WordList(['condom', 'use']),
#  WordList(['use', 'group']),
#  WordList(['group', 'took']),
#  WordList(['took', 'pill']),
#  WordList(['pill', 'wonât']),
#  WordList(['wonât', 'finding']),
#  WordList(['finding', 'encourage']),
#  WordList(['encourage', 'men']),
#  WordList(['men', 'dispense']),
#  WordList(['dispense', 'condom']),
#  WordList(['condom', 'altogether']),
#  WordList(['altogether', 'favour']),
#  WordList(['favour', 'drug']),
#  WordList(['drug', 'issue']),
#  WordList(['issue', 'prohibitive']),
#  WordList(['prohibitive', 'cost']),
#  WordList(['cost', 'truvada']),
#  WordList(['truvada', 'retail']),
#  WordList(['retail', 'u']),
#  WordList(['u', 'around']),
#  WordList(['around', '36']),
#  WordList(['36', 'day']),
#  WordList(['day', 'make']),
#  WordList(['make', 'drug']),
#  WordList(['drug', 'unaffordable']),
#  WordList(['unaffordable', 'many']),
#  WordList(['many', 'possible']),
#  WordList(['possible', 'user']),
#  WordList(['user', 'dr']),
#  WordList(['dr', 'fauci']),
#  WordList(['fauci', 'argues']),
#  WordList(['argues', 'two']),
#  WordList(['two', 'group']),
#  WordList(['group', 'fully']),
#  WordList(['fully', 'randomised']),
#  WordList(['randomised', 'say']),
#  WordList(['say', 'drug']),
#  WordList(['drug', 'play']),
#  WordList(['play', 'complementary']),
#  WordList(['complementary', 'role']),
#  WordList(['role', 'war']),
#  WordList(['war', 'condom']),
#  WordList(['condom', 'fewer']),
#  WordList(['fewer', 'partner']),
#  WordList(['partner', 'remain']),
#  WordList(['remain', 'first']),
#  WordList(['first', 'line']),
#  WordList(['line', 'defence']),
#  WordList(['defence', 'âœweâre']),
#  WordList(['âœweâre', 'hoping']),
#  WordList(['hoping', 'become']),
#  WordList(['become', 'useable']),
#  WordList(['useable', 'tool']),
#  WordList(['tool', 'prevention']),
#  WordList(['prevention', 'associated']),
#  WordList(['associated', 'counselling']),
#  WordList(['counselling', 'complement']),
#  WordList(['complement', 'effect']),
#  WordList(['effect', 'drug']),
#  WordList(['drug', 'stop']),
#  WordList(['stop', 'becoming']),
#  WordList(['becoming', 'cavalier']),
#  WordList(['cavalier', 'say']),
#  WordList(['say', 'ânow']),
#  WordList(['ânow', 'pill']),
#  WordList(['pill', 'donât']),
#  WordList(['donât', 'worryâ']),
#  WordList(['worryâ', 'âœthatâs']),
#  WordList(['âœthatâs', 'exactly']),
#  WordList(['exactly', 'opposite']),
#  WordList(['opposite', 'want']),
#  WordList(['want', 'happen']),
#  WordList(['happen', 'want']),
#  WordList(['want', 'add']),
#  WordList(['add', 'something']),
#  WordList(['something', 'rather']),
#  WordList(['rather', 'replace']),
#  WordList(['replace', 'somethingâ']),
#  WordList(['somethingâ', 'sir']),
#  WordList(['sir', 'nick']),
#  WordList(['nick', 'partridge']),
#  WordList(['partridge', 'chief']),
#  WordList(['chief', 'executive']),
#  WordList(['executive', 'terrence']),
#  WordList(['terrence', 'higgins']),
#  WordList(['higgins', 'trust']),
#  WordList(['trust', 'called']),
#  WordList(['called', 'trial']),
#  WordList(['trial', 'result']),
#  WordList(['result', 'âœpotentially']),
#  WordList(['âœpotentially', 'significantâ']),
#  WordList(['significantâ', 'âœitâs']),
#  WordList(['âœitâs', 'vital']),
#  WordList(['vital', 'expand']),
#  WordList(['expand', 'way']),
#  WordList(['way', 'prevent']),
#  WordList(['prevent', 'transmission']),
#  WordList(['transmission', 'particularly']),
#  WordList(['particularly', 'amongst']),
#  WordList(['amongst', 'riskâ']),
#  WordList(['riskâ', 'statement']),
#  WordList(['statement', 'âœthis']),
#  WordList(['âœthis', 'trial']),
#  WordList(['trial', 'prof']),
#  WordList(['prof', 'impact']),
#  WordList(['impact', 'prevention']),
#  WordList(['prevention', 'itâs']),
#  WordList(['itâs', 'ready']),
#  WordList(['ready', 'widespread']),
#  WordList(['widespread', 'use']),
#  WordList(['use', 'yet']),
#  WordList(['yet', 'âœthree']),
#  WordList(['âœthree', 'major']),
#  WordList(['major', 'hurdle']),
#  WordList(['hurdle', 'still']),
#  WordList(['still', 'going']),
#  WordList(['going', 'cost']),
#  WordList(['cost', 'risk']),
#  WordList(['risk', 'drugresistant']),
#  WordList(['drugresistant', 'strain']),
#  WordList(['strain', 'developing']),
#  WordList(['developing', 'taking']),
#  WordList(['taking', 'drug']),
#  WordList(['drug', 'every']),
#  WordList(['every', 'dayâ']),
#  WordList(['dayâ', 'source']),
#  WordList(['source', 'bbc'])]

# %% [markdown]
# ### Term Frequency

# %%
tf1 = (train['Articles'][1:2]).apply(lambda x: pd.value_counts(x.split(" "))).sum(axis = 0).reset_index()
tf1.columns = ['words','tf']
tf1
# Out:
#                words  tf
# 0        afghanistan   7
# 1              virus   6
# 2               case   6
# 3             public   5
# 4               drug   5
# 5           recorded   5
# 6           positive   5
# 7         individual   4
# 8                 dr   4
# 9             paikan   4
# 10            latest   3
# 11          official   3
# 12         statistic   3
# 13          ministry   3
# 14             human   2
# 15  immunodeficiency   2
# 16            number   2
# 17            mainly   2
# 18           country   2
# 19          mohammad   2
# 20              fida   2
# 21          majority   2
# 22         according   2
# 23             least   2
# 24              1367   2
# 25               end   2
# 26             using   2
# 27          affected   2
# 28              flow   1
# 29            coming   1
# ..               ...  ..
# 55             kabul   1
# 56           capital   1
# 57            inject   1
# 58           include   1
# 59            saying   1
# 60       volunteerly   1
# 61           migrant   1
# 62                un   1
# 63             added   1
# 64            across   1
# 65          worrying   1
# 66      organization   1
# 67           provide   1
# 68              2012   1
# 69            lowest   1
# 70             world   1
# 71              5000   1
# 72           syringe   1
# 73              done   1
# 74       transferred   1
# 75              test   1
# 76          addicted   1
# 77           prevent   1
# 78            nation   1
# 79          province   1
# 80               bid   1
# 81           badghis   1
# 82            united   1
# 83      transferring   1
# 84              2011   1
#
# [85 rows x 2 columns]

# %% [markdown]
# ### Inverse Document Frequency

# %%
for i,word in enumerate(tf1['words']):
    tf1.loc[i, 'idf'] = np.log(train.shape[0]/(len(train[train['Articles'].str.contains(word)])))
tf1
# Out:
#                words  tf       idf
# 0        afghanistan   7  2.995732
# 1              virus   6  1.251040
# 2               case   6  0.951382
# 3             public   5  1.306782
# 4               drug   5  0.899196
# 5           recorded   5  2.556366
# 6           positive   5  0.987750
# 7         individual   4  2.866521
# 8                 dr   4  0.361613
# 9             paikan   4  6.363028
# 10            latest   3  1.275432
# 11          official   3  1.450373
# 12         statistic   3  2.625358
# 13          ministry   3  1.110755
# 14             human   2  1.830429
# 15  immunodeficiency   2  2.961831
# 16            number   2  0.964865
# 17            mainly   2  3.418589
# 18           country   2  0.916291
# 19          mohammad   2  3.798079
# 20              fida   2  6.363028
# 21          majority   2  3.104932
# 22         according   2  0.969401
# 23             least   2  2.204145
# 24              1367   2  6.363028
# 25               end   2  0.389218
# 26             using   2  1.728299
# 27          affected   2  2.072569
# 28              flow   1  3.798079
# 29            coming   1  2.143520
# ..               ...  ..       ...
# 55             kabul   1  3.227534
# 56           capital   1  3.318506
# 57            inject   1  2.128922
# 58           include   1  2.219893
# 59            saying   1  2.929041
# 60       volunteerly   1  6.363028
# 61           migrant   1  3.472656
# 62                un   1  0.020907
# 63             added   1  1.443047
# 64            across   1  2.188641
# 65          worrying   1  4.417118
# 66      organization   1  2.355695
# 67           provide   1  1.054760
# 68              2012   1  2.578838
# 69            lowest   1  4.753590
# 70             world   1  1.326076
# 71              5000   1  2.072569
# 72           syringe   1  3.798079
# 73              done   1  1.359082
# 74       transferred   1  3.965133
# 75              test   1  0.496560
# 76          addicted   1  3.418589
# 77           prevent   1  0.579203
# 78            nation   1  0.420229
# 79          province   1  1.137281
# 80               bid   1  3.227534
# 81           badghis   1  5.669881
# 82            united   1  1.944187
# 83      transferring   1  4.976734
# 84              2011   1  2.752110
#
# [85 rows x 3 columns]

# %% [markdown]
# ### Term Frequency – Inverse Document Frequency (TF-IDF)

# %%
tf1['tfidf'] = tf1['tf'] * tf1['idf']
tf1
# Out:
#                words  tf       idf      tfidf
# 0        afghanistan   7  2.995732  20.970126
# 1              virus   6  1.251040   7.506242
# 2               case   6  0.951382   5.708292
# 3             public   5  1.306782   6.533911
# 4               drug   5  0.899196   4.495981
# 5           recorded   5  2.556366  12.781828
# 6           positive   5  0.987750   4.938748
# 7         individual   4  2.866521  11.466082
# 8                 dr   4  0.361613   1.446453
# 9             paikan   4  6.363028  25.452112
# 10            latest   3  1.275432   3.826295
# 11          official   3  1.450373   4.351120
# 12         statistic   3  2.625358   7.876075
# 13          ministry   3  1.110755   3.332264
# 14             human   2  1.830429   3.660857
# 15  immunodeficiency   2  2.961831   5.923661
# 16            number   2  0.964865   1.929731
# 17            mainly   2  3.418589   6.837178
# 18           country   2  0.916291   1.832581
# 19          mohammad   2  3.798079   7.596157
# 20              fida   2  6.363028  12.726056
# 21          majority   2  3.104932   6.209863
# 22         according   2  0.969401   1.938801
# 23             least   2  2.204145   4.408290
# 24              1367   2  6.363028  12.726056
# 25               end   2  0.389218   0.778437
# 26             using   2  1.728299   3.456598
# 27          affected   2  2.072569   4.145137
# 28              flow   1  3.798079   3.798079
# 29            coming   1  2.143520   2.143520
# ..               ...  ..       ...        ...
# 55             kabul   1  3.227534   3.227534
# 56           capital   1  3.318506   3.318506
# 57            inject   1  2.128922   2.128922
# 58           include   1  2.219893   2.219893
# 59            saying   1  2.929041   2.929041
# 60       volunteerly   1  6.363028   6.363028
# 61           migrant   1  3.472656   3.472656
# 62                un   1  0.020907   0.020907
# 63             added   1  1.443047   1.443047
# 64            across   1  2.188641   2.188641
# 65          worrying   1  4.417118   4.417118
# 66      organization   1  2.355695   2.355695
# 67           provide   1  1.054760   1.054760
# 68              2012   1  2.578838   2.578838
# 69            lowest   1  4.753590   4.753590
# 70             world   1  1.326076   1.326076
# 71              5000   1  2.072569   2.072569
# 72           syringe   1  3.798079   3.798079
# 73              done   1  1.359082   1.359082
# 74       transferred   1  3.965133   3.965133
# 75              test   1  0.496560   0.496560
# 76          addicted   1  3.418589   3.418589
# 77           prevent   1  0.579203   0.579203
# 78            nation   1  0.420229   0.420229
# 79          province   1  1.137281   1.137281
# 80               bid   1  3.227534   3.227534
# 81           badghis   1  5.669881   5.669881
# 82            united   1  1.944187   1.944187
# 83      transferring   1  4.976734   4.976734
# 84              2011   1  2.752110   2.752110
#
# [85 rows x 4 columns]

# %%
tfidf = TfidfVectorizer(max_features=1000, lowercase=True, analyzer='word',
 stop_words= 'english',ngram_range=(1,1))
train_vect = tfidf.fit_transform(train['Articles'])

train_vect
# Out:
# <580x1000 sparse matrix of type '<class 'numpy.float64'>'
# 	with 52291 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ### Bag of Words

# %%
bow = CountVectorizer(max_features=1000, lowercase=True, ngram_range=(1,1),analyzer = "word")
train_bow = bow.fit_transform(train['Articles'])
train_bow
# Out:
# <580x1000 sparse matrix of type '<class 'numpy.int64'>'
# 	with 57246 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ### Sentiment Analysis

# %%
train['Articles'][:5].apply(lambda x: TextBlob(x).sentiment)
# Out:
# 0    (0.16425026123301986, 0.47387870749939726)
# 1    (0.07407822062994475, 0.38189281982385437)
# 2     (0.05241341991341991, 0.3787445887445887)
# 3    (-0.05832696715049657, 0.3053093964858671)
# 4     (0.1706293706293706, 0.40209790209790214)
# Name: Articles, dtype: object

# %%
train['sentiment'] = train['Articles'].apply(lambda x: TextBlob(x).sentiment[0] )
train[['Articles','sentiment']].head()
# Out:
#                                             Articles  sentiment
# 0  drug used treat hivpositive patient may offer ...   0.164250
# 1  least 1367 positive case human immunodeficienc...   0.074078
# 2  official ministry public afghanistan informed ...   0.052413
# 3  today mark world day time global community rec...  -0.058327
# 4  united nation monday announced addition bollyw...   0.170629

# %% [markdown]
# ### Word Embeddings

# %%
glove_input_file = 'glove.6B.100d.txt'
word2vec_output_file = 'glove.6B.100d.txt.word2vec'
glove2word2vec(glove_input_file, word2vec_output_file)
# Out:
# (400000, 100)

# %%
filename = 'glove.6B.100d.txt.word2vec'
model = KeyedVectors.load_word2vec_format(filename, binary=False)

# %%
model['go']
# Out:
# array([-0.078894,  0.4616  ,  0.57779 , -0.71637 , -0.13121 ,  0.4186  ,
#        -0.29156 ,  0.52006 ,  0.089986, -0.35062 ,  0.51755 ,  0.51998 ,
#         0.15218 ,  0.41485 , -0.12377 , -0.37222 ,  0.0273  ,  0.75673 ,
#        -0.8739  ,  0.58935 ,  0.46662 ,  0.62918 ,  0.092603, -0.012868,
#        -0.015169,  0.25567 , -0.43025 , -0.77668 ,  0.71449 , -0.3834  ,
#        -0.69638 ,  0.23522 ,  0.11396 ,  0.02778 ,  0.071357,  0.87409 ,
#        -0.1281  ,  0.063576,  0.067867, -0.50181 , -0.28523 , -0.072536,
#        -0.50738 , -0.6914  , -0.53579 , -0.11361 , -0.38234 , -0.12414 ,
#         0.011214, -1.1622  ,  0.037057, -0.18495 ,  0.01416 ,  0.87193 ,
#        -0.097309, -2.3565  , -0.14554 ,  0.28275 ,  2.0053  ,  0.23439 ,
#        -0.38298 ,  0.69539 , -0.44916 , -0.094157,  0.90527 ,  0.65764 ,
#         0.27628 ,  0.30688 , -0.57781 , -0.22987 , -0.083043, -0.57236 ,
#        -0.299   , -0.81112 ,  0.039752, -0.05681 , -0.48879 , -0.18091 ,
#        -0.28152 , -0.20559 ,  0.4932  , -0.033999, -0.53139 , -0.28297 ,
#        -1.4475  , -0.18685 ,  0.091177,  0.11454 , -0.28168 , -0.33565 ,
#        -0.31663 , -0.1089  ,  0.10111 , -0.23737 , -0.64955 , -0.268   ,
#         0.35096 ,  0.26352 ,  0.59397 ,  0.26741 ], dtype=float32)

# %%
model['away']
# Out:
# array([-0.10379 , -0.014792,  0.59933 , -0.51316 , -0.036463,  0.6588  ,
#        -0.57906 ,  0.17819 ,  0.23663 , -0.21384 ,  0.55339 ,  0.53597 ,
#         0.041444,  0.16095 ,  0.017093, -0.37242 ,  0.017974,  0.39268 ,
#        -0.23265 ,  0.1818  ,  0.66405 ,  0.98163 ,  0.42339 ,  0.030581,
#         0.35015 ,  0.25519 , -0.71182 , -0.42184 ,  0.13068 , -0.47452 ,
#        -0.08175 ,  0.1574  , -0.13262 ,  0.22679 , -0.16885 , -0.11122 ,
#        -0.32272 , -0.020978, -0.43345 ,  0.172   , -0.67366 , -0.79052 ,
#         0.10556 , -0.4219  , -0.12385 , -0.063486, -0.17843 ,  0.56359 ,
#         0.16986 , -0.17804 ,  0.13956 , -0.20169 ,  0.078985,  1.4497  ,
#         0.23556 , -2.6014  , -0.5286  , -0.11636 ,  1.7184  ,  0.33254 ,
#         0.12136 ,  1.1602  , -0.2914  ,  0.47125 ,  0.41869 ,  0.35271 ,
#         0.47869 , -0.042281, -0.18294 ,  0.1796  , -0.24431 , -0.34042 ,
#         0.20337 , -0.93676 ,  0.013077,  0.080339, -0.36604 , -0.44005 ,
#        -0.35393 ,  0.15907 ,  0.55807 ,  0.1492  , -0.86433 ,  0.040305,
#        -1.0939  , -0.26386 , -0.29494 ,  0.25696 , -0.33718 , -0.086468,
#        -0.24246 , -0.21114 ,  0.099632,  0.12815 , -0.78714 , -0.51785 ,
#        -0.10944 ,  0.9763  ,  0.57032 ,  0.13581 ], dtype=float32)

# %%
(model['go'] + model['away'])/2
# Out:
# array([-0.091342  ,  0.223404  ,  0.58856   , -0.614765  , -0.0838365 ,
#         0.5387    , -0.43531   ,  0.349125  ,  0.163308  , -0.28223   ,
#         0.53547   ,  0.52797496,  0.096812  ,  0.2879    , -0.0533385 ,
#        -0.37232   ,  0.022637  ,  0.574705  , -0.553275  ,  0.385575  ,
#         0.565335  ,  0.805405  ,  0.2579965 ,  0.0088565 ,  0.1674905 ,
#         0.25543   , -0.571035  , -0.59926   ,  0.422585  , -0.42896   ,
#        -0.389065  ,  0.19631   , -0.00933   ,  0.127285  , -0.0487465 ,
#         0.381435  , -0.22540998,  0.021299  , -0.1827915 , -0.16490501,
#        -0.47944498, -0.431528  , -0.20091   , -0.55665   , -0.32982   ,
#        -0.088548  , -0.28038502,  0.219725  ,  0.090537  , -0.67012   ,
#         0.0883085 , -0.19332   ,  0.0465725 ,  1.160815  ,  0.0691255 ,
#        -2.47895   , -0.33707   ,  0.083195  ,  1.86185   ,  0.283465  ,
#        -0.13081   ,  0.927795  , -0.37028   ,  0.1885465 ,  0.66198   ,
#         0.505175  ,  0.37748498,  0.1322995 , -0.380375  , -0.025135  ,
#        -0.1636765 , -0.45639   , -0.047815  , -0.87394   ,  0.0264145 ,
#         0.0117645 , -0.427415  , -0.31048   , -0.317725  , -0.02326   ,
#         0.525635  ,  0.05760051, -0.69786   , -0.1213325 , -1.2707    ,
#        -0.225355  , -0.1018815 ,  0.18575001, -0.30943   , -0.211059  ,
#        -0.279545  , -0.16002001,  0.100371  , -0.05461   , -0.71834505,
#        -0.392925  ,  0.12075999,  0.61991   ,  0.582145  ,  0.20161   ],
#       dtype=float32)
