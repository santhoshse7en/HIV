# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import matplotlib.pyplot as plt
import matplotlib
matplotlib.style.use('ggplot')

# %%
data = pd.read_csv('Final_HIV_without_Nan.csv')
data.head()
# Out:
#                                            Headlines  \
# 0  Drug â€˜can greatly reduce risk of HIV infecti...
# 1  Afghanistan recorded 1367 HIV/AIDS positive ca...
# 2  Afghanistan sees 38 percent increase in HIV/AI...
# 3  Over 1,200 people live with HIV in Afghanistan...
# 4     Aishwarya Rai Bachchan named UN HIV/AIDS envoy
#
#                                       Descriptions               Authors  \
# 0  The largest online news service for Afghanistan          Khaama Press
# 1  The largest online news service for Afghanistan  Ahmad Shah Ghanizada
# 2  The largest online news service for Afghanistan  Ahmad Shah Ghanizada
# 3  The largest online news service for Afghanistan           Sayed Jawad
# 4  The largest online news service for Afghanistan                 Sajad
#
#   Published_Dates                   Publication  \
# 0      25-11-2010  The Khaama Press News Agency
# 1      06-07-2013  The Khaama Press News Agency
# 2      01-12-2013  The Khaama Press News Agency
# 3      01-12-2012  The Khaama Press News Agency
# 4      25-09-2012  The Khaama Press News Agency
#
#                                             Articles category  \
# 0  A drug used to treat HIV-positive patients may...       {}
# 1  At least 1,367 positive cases of Human immunod...       {}
# 2  Officials in the ministry of public health of ...       {}
# 3  Today marks World AIDS Day, a time for the glo...       {}
# 4  The United Nations Monday announced the additi...       {}
#
#                                             Keywords  \
# 0  ['drug', 'reduce', 'infection', 'results', 'us...
# 1  ['afghanistan', 'paikan', 'positive', '2011', ...
# 2  ['afghanistan', 'positive', 'sees', 'virus', '...
# 3  ['immunodeficiency', '1200', 'aids', 'afghanis...
# 4  ['infections', 'mother', 'aishwarya', 'rai', '...
#
#                                            Summaries  \
# 0  A drug used to treat HIV-positive patients may...
# 1  At least 1,367 positive cases of Human immunod...
# 2  Officials in the ministry of public health of ...
# 3  Today marks World AIDS Day, a time for the glo...
# 4  The United Nations Monday announced the additi...
#
#                                          Source_URLs
# 0  https://www.khaama.com/drug-can-greatly-reduce...
# 1  https://www.khaama.com/afghanistan-recorded-13...
# 2  https://www.khaama.com/afghanistan-sees-38-per...
# 3  https://www.khaama.com/over-1200-people-live-w...
# 4  https://www.khaama.com/aishwarya-rai-bachchan-...

# %%
print("Types and counts of publication", data.groupby(['Publication']).size())
# Out:
# Types and counts of publication Publication
# The Jakarta Post                147
# The Kabul Times                  18
# The Khaama Press News Agency     25
# The Times of India              139
# vietnamnews.vn                  251
# dtype: int64

# %%
data.groupby(['Publication']).size().plot(kind='bar')

# %%
vietnamnews = data[data["Publication"] == "vietnamnews.vn"]

# %%
import nltk

# Fill any blank fields
vietnamnews.Headlines.fillna("", inplace=True)
vietnamnews.Articles.fillna("", inplace=True)

# Join the Headlines and Articles
all_Articles = vietnamnews.Headlines.str.cat(vietnamnews.Articles, sep=' ')

# Tokenize. The NLTK tokenizer isn't awesome. Spacy has a nice one, but I don't think it is installed
words = nltk.word_tokenize(" ".join(all_Articles.tolist()))
# Out:
# C:\Users\GM\Anaconda3\lib\site-packages\pandas\core\generic.py:6130: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
vietnamnews.head()
# Out:
#                                              Headlines  \
# 329         Number of HIV/AIDS cases continues to fall
# 330                     HIV increase sparks free tests
# 331   HIV testing and treatment for an AIDS-free world
# 332  Localities to strengthen HIV/AIDS control and ...
# 333  VN has work to do in HIV prevention and treatment
#
#                                           Descriptions Authors  \
# 329  The number of HIV/AIDS cases in Viá»‡t Nam con...      []
# 330  The Ministry of Health has asked the northern ...      []
# 331  The Human Immunodeficiency Virus (HIV) is spre...      []
# 332  The Ministry of Health has asked provinces and...      []
# 333  About 50,000 people living with HIV in Viá»‡t ...      []
#
#     Published_Dates     Publication  \
# 329      2018-12-03  vietnamnews.vn
# 330      2018-08-17  vietnamnews.vn
# 331      2018-06-25  vietnamnews.vn
# 332      2018-10-30  vietnamnews.vn
# 333      2018-11-17  vietnamnews.vn
#
#                                               Articles      category  \
# 329  HCM CITYâ€“ The number of HIV/AIDS cases in Vi...       Society
# 330  A delegation from the health ministry visits r...       Society
# 331  By Dr Mathieu Nalpas* The Human Immunodeficien...  Life & Style
# 332  HÃ€ Ná»˜I â€” The Ministry of Health has asked...       Society
# 333  HÃ€ Ná»˜I â€” About 50,000 people living with ...       Society
#
#                                               Keywords  \
# 329  ['cases', 'number', 'prep', 'services', 'viá»‡...
# 330  ['ministry', 'thÆ°á»£ng', 'patients', 'hiv', '...
# 331  ['testing', 'medical', 'status', 'viá»‡t', 'li...
# 332  ['ministry', 'localities', 'strengthen', 'livi...
# 333  ['patients', 'viá»‡t', 'vn', 'hiv', 'nam', 'li...
#
#                                              Summaries  \
# 329  HCM CITYâ€“ The number of HIV/AIDS cases in Vi...
# 330  A delegation from the health ministry visits r...
# 331  By Dr Mathieu Nalpas*The Human Immunodeficienc...
# 332  HÃ€ Ná»˜I â€” The Ministry of Health has asked...
# 333  HÃ€ Ná»˜I â€” About 50,000 people living with ...
#
#                                            Source_URLs
# 329  http://vietnamnews.vn/society/481242/number-of...
# 330  http://vietnamnews.vn/society/463991/hiv-incre...
# 331  http://vietnamnews.vn/life-style/450345/hiv-te...
# 332  http://vietnamnews.vn/society/468834/localitie...
# 333  http://vietnamnews.vn/society/480271/vn-has-wo...

# %%
from nltk.corpus import stopwords
import string

# clearly more cleaning is needed here, but really I should get a better tokenizer
stop = stopwords.words('english') 
cleanwords = [i for i in words if i not in stop and i.isalpha() and len(i) > 2]

# %%
from wordcloud import WordCloud, STOPWORDS

wordcloud2 = WordCloud(
                          stopwords=STOPWORDS,
                          background_color='white',
                          width=1200,
                          height=1000
                         ).generate(" ".join(cleanwords))


plt.imshow(wordcloud2)
plt.axis('off')
plt.show()

# %%
# Bigrams should be more interesting

bigrams = nltk.bigrams(cleanwords)

# %%
# look at the most common. 

from collections import Counter

counter = Counter(bigrams)
print(counter.most_common(10))
# Out:
# [(('per', 'cent'), 506), (('Viet', 'Nam'), 417), (('Viá', 'Nam'), 265), (('people', 'living'), 243), (('HCM', 'City'), 231), (('health', 'insurance'), 196), (('living', 'HIV'), 194), (('cent', 'people'), 103), (('people', 'HIV'), 96), (('Ministry', 'Health'), 82)]

# %%
num_to_show = 30

labels = [" ".join(e[0]) for e in counter.most_common(num_to_show)]
values = [e[1] for e in counter.most_common(num_to_show)]

indexes = np.arange(len(labels))
width = 1

plt.bar(indexes, values, width)
plt.xticks(indexes + width * 0.5, labels, rotation=90)

#plt.barh(indexes, values, width)
#plt.yticks(indexes + width * 0.2, labels)
plt.show()
